# %% [markdown]
# # 🚀 `Análisis de Siniestros` (KPIs)

# %% [markdown]
# En este notebook se realiza el análisis de los siniestros viales de la Ciudad Autónoma de Buenos Aires, con el fin de generar información que le permita a las autoridades locales tomar medidas para disminuir la cantidad de víctimas fatales de los siniestros viales. Para ello, se proporcionó un conjunto de datos en formato .xlsx, el cuál se describe en el documento `Diccionario_de_Datos` y al cuál se le realizó la correspondiente limpieza y Análisis Exploratorio de Datos que se puede consultar en el documento `EDA`.

# %% [markdown]
# #### 📥Importaciones

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 📦 Extracción de los datos y primera exploración

# %% [markdown]
# Se extraen los datos del archivo csv y se convierte en Dataframe.

# %%
df_homicidios = pd.read_csv('Datasets/Archivos_PBI/homicidios_limpio.csv')
df_homicidios
# Out:
#                       ROL VICTIMA       SEXO  EDAD  FECHA_FALLECIMIENTO  \
# 0               Conductor    Moto  Masculino    19  2016-01-01 00:00:00
# 1               Conductor    Auto  Masculino    70  2016-01-02 00:00:00
# 2               Conductor    Moto  Masculino    30  2016-01-03 00:00:00
# 3               Conductor    Moto  Masculino    29  2016-02-01 00:00:00
# 4               Conductor    Moto  Masculino    30  2016-01-24 00:00:00
# ..                    ...     ...        ...   ...                  ...
# 685                Peaton  Peaton   Femenino    50  2021-12-12 00:00:00
# 686  Pasajero_Acompañante    Moto   Femenino    18  2021-12-18 00:00:00
# 687  Pasajero_Acompañante    Moto   Femenino    43  2021-12-20 00:00:00
# 688             Conductor    Moto  Masculino    27  2022-01-02 00:00:00
# 689             Conductor    Auto  Masculino    60  2021-12-20 00:00:00
#
#      N_VICTIMAS FECHA_SINIESTRO HORA_SINIESTRO  HH  \
# 0             1      2016-01-01       04:00:00   4
# 1             1      2016-01-02       01:15:00   1
# 2             1      2016-01-03       07:00:00   7
# 3             1      2016-01-21       05:20:00   5
# 4             1      2016-01-24       18:30:00  18
# ..          ...             ...            ...  ..
# 685           1      2021-12-12       06:20:00   6
# 686           1      2021-12-13       17:10:00  17
# 687           1      2021-12-20       01:10:00   1
# 688           1      2021-12-30       00:43:00   0
# 689           1      2021-12-15       10:30:00  10
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  COMUNA  \
# 0    Av Piedra Buena Y Av Fernandez De La Cruz       Avenida       8
# 1            Av Gral Paz  Y Av De Los Corrales      Gral Paz       9
# 2                           Av Entre Rios 2034       Avenida       1
# 3    Av San Juan Y Presidente Luis Saenz Peña        Avenida       1
# 4               Av 27 De Febrero Y Av Escalada       Avenida       8
# ..                                         ...           ...     ...
# 685             Av. Rivadavia Y Av. Pueyrredon       Avenida       3
# 686                          Av. Riestra Y Mom       Avenida       7
# 687                    Au Dellepiane Y Lacarra     Autopista       9
# 688                        Av. Gaona Y Terrada       Avenida      11
# 689                         Av. Eva Peron 4071       Avenida       9
#
#             pos x         pos y     PARTICIPANTES      ACUSADO   ID  Year  \
# 0    -58.47533969  -34.68757022         Moto-Auto         Auto    1  2016
# 1    -58.50877521  -34.66977709    Auto-Pasajeros    Pasajeros    2  2016
# 2    -58.39040293  -34.63189362         Moto-Auto         Auto    3  2016
# 3    -58.38718297  -34.62246630    Moto-Pasajeros    Pasajeros    4  2016
# 4    -58.44451316  -34.68475866  Moto-Objeto Fijo  Objeto Fijo    5  2016
# ..            ...           ...               ...          ...  ...   ...
# 685  -58.40596860  -34.61011987       Peaton-Auto         Auto  686  2021
# 686  -58.43353773  -34.64561636         Moto-Auto         Auto  687  2021
# 687  -58.46739825  -34.65117757         Moto-Auto         Auto  688  2021
# 688  -58.47293407  -34.61984745       Moto-Cargas       Cargas  689  2021
# 689  -58.47066794  -34.65021673       Auto-Cargas       Cargas  690  2021
#
#     Rango_Edad
# 0         1-20
# 1        61-90
# 2        21-40
# 3        21-40
# 4        21-40
# ..         ...
# 685      41-60
# 686       1-20
# 687      41-60
# 688      21-40
# 689      61-90
#
# [690 rows x 19 columns]

# %% [markdown]
# #### 🚀 KPI 1: Reducir en un 10% la tasa de homicidios en siniestros viales de los últimos seis meses, en CABA, en comparación con la tasa de homicidios en siniestros viales del semestre anterior.

# %% [markdown]
# #### 🚀 KPI 2: Reducir en un 7% la cantidad de accidentes mortales de motociclistas en el último año, en CABA, respecto al año anterior.

# %% [markdown]
# Se realiza un codigo que integre las fechas del siniestro en semestres para el informe de rendimiento.

# %%
df_homicidios['FECHA_SINIESTRO'] = pd.to_datetime(df_homicidios['FECHA_SINIESTRO'])
df_homicidios['semestre'] = [1 if month <= 6 else 2 for month in df_homicidios['FECHA_SINIESTRO'].dt.month]
df_homicidios.head(2)
# Out:
#          ROL VICTIMA       SEXO  EDAD  FECHA_FALLECIMIENTO  N_VICTIMAS  \
# 0  Conductor    Moto  Masculino    19  2016-01-01 00:00:00           1
# 1  Conductor    Auto  Masculino    70  2016-01-02 00:00:00           1
#
#   FECHA_SINIESTRO HORA_SINIESTRO HH  \
# 0      2016-01-01       04:00:00  4
# 1      2016-01-02       01:15:00  1
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  COMUNA  \
# 0  Av Piedra Buena Y Av Fernandez De La Cruz       Avenida       8
# 1          Av Gral Paz  Y Av De Los Corrales      Gral Paz       9
#
#           pos x         pos y   PARTICIPANTES    ACUSADO  ID  Year Rango_Edad  \
# 0  -58.47533969  -34.68757022       Moto-Auto       Auto   1  2016       1-20
# 1  -58.50877521  -34.66977709  Auto-Pasajeros  Pasajeros   2  2016      61-90
#
#    semestre
# 0         1
# 1         1

# %% [markdown]
# Se realiza un conteo de nuestros "SinDato" para saber si debemos continuar con el análisis o podemos pasar a la siguiente etapa.

# %%
conteo_sd = df_homicidios.apply(lambda x: x.value_counts().get('Sd', 0))
conteo_sd
# Out:
# ROL                    2
# VICTIMA                0
# SEXO                   2
# EDAD                   0
# FECHA_FALLECIMIENTO    0
# N_VICTIMAS             0
# FECHA_SINIESTRO        0
# HORA_SINIESTRO         0
# HH                     0
# LUGAR_DEL_HECHO        0
# TIPO_DE_CALLE          0
# COMUNA                 0
# pos x                  0
# pos y                  0
# PARTICIPANTES          0
# ACUSADO                0
# ID                     0
# Year                   0
# Rango_Edad             0
# semestre               0
# dtype: int64

# %% [markdown]
# Se reorganiza la direccion.

# %%
def reorganizar_direcc(address):
    words = address.split()
    if "Av." in words:
        words.remove("Av.")
        words = ["Av."] + words
    return " ".join(words)

df_homicidios['LUGAR_DEL_HECHO'] = df_homicidios['LUGAR_DEL_HECHO'].apply(reorganizar_direcc)

# %% [markdown]
# Se elimina la columna "HH" ya que representa el entero de las horas, pero lo redondea a la hora dada sin contemplar un redondeo sobre los minutos.

# %%
df_homicidios = df_homicidios.drop(columns=['HH'])
df_homicidios.head(2)
# Out:
#          ROL VICTIMA       SEXO  EDAD  FECHA_FALLECIMIENTO  N_VICTIMAS  \
# 0  Conductor    Moto  Masculino    19  2016-01-01 00:00:00           1
# 1  Conductor    Auto  Masculino    70  2016-01-02 00:00:00           1
#
#   FECHA_SINIESTRO HORA_SINIESTRO                            LUGAR_DEL_HECHO  \
# 0      2016-01-01       04:00:00  Av Piedra Buena Y Av Fernandez De La Cruz
# 1      2016-01-02       01:15:00           Av Gral Paz Y Av De Los Corrales
#
#   TIPO_DE_CALLE  COMUNA         pos x         pos y   PARTICIPANTES  \
# 0       Avenida       8  -58.47533969  -34.68757022       Moto-Auto
# 1      Gral Paz       9  -58.50877521  -34.66977709  Auto-Pasajeros
#
#      ACUSADO  ID  Year Rango_Edad  semestre
# 0       Auto   1  2016       1-20         1
# 1  Pasajeros   2  2016      61-90         1

# %%
df_homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ROL                  690 non-null    object
#  1   VICTIMA              690 non-null    object
#  2   SEXO                 690 non-null    object
#  3   EDAD                 690 non-null    int64
#  4   FECHA_FALLECIMIENTO  690 non-null    object
#  5   N_VICTIMAS           690 non-null    int64
#  6   FECHA_SINIESTRO      690 non-null    datetime64[ns]
#  7   HORA_SINIESTRO       690 non-null    object
#  8   LUGAR_DEL_HECHO      690 non-null    object
#  9   TIPO_DE_CALLE        690 non-null    object
#  10  COMUNA               690 non-null    int64
#  11  pos x                690 non-null    object
#  12  pos y                690 non-null    object
#  13  PARTICIPANTES        690 non-null    object
#  14  ACUSADO              690 non-null    object
#  15  ID                   690 non-null    int64
#  16  Year                 690 non-null    int64
#  17  Rango_Edad           686 non-null    object
#  18  semestre             690 non-null    int64
# dtypes: datetime64[ns](1), int64(6), object(12)
# memory usage: 102.5+ KB

# %% [markdown]
# Se cambian las columnas 'pos x' y 'pos y' a valores numericos.

# %%
# Convierte la columna 'pos x' a valores numéricos
df_homicidios['pos x'] = pd.to_numeric(df_homicidios['pos x'], errors='coerce')

# Convierte la columna 'pos y' a valores numéricos
df_homicidios['pos y'] = pd.to_numeric(df_homicidios['pos y'], errors='coerce')

# %% [markdown]
# Se cambia el nombre de la columna 'Year' a 'Anio'.

# %%
df_homicidios = df_homicidios.rename(columns={'Year': 'Anio'})
df_homicidios.head(2)
# Out:
#          ROL VICTIMA       SEXO  EDAD  FECHA_FALLECIMIENTO  N_VICTIMAS  \
# 0  Conductor    Moto  Masculino    19  2016-01-01 00:00:00           1
# 1  Conductor    Auto  Masculino    70  2016-01-02 00:00:00           1
#
#   FECHA_SINIESTRO HORA_SINIESTRO                            LUGAR_DEL_HECHO  \
# 0      2016-01-01       04:00:00  Av Piedra Buena Y Av Fernandez De La Cruz
# 1      2016-01-02       01:15:00           Av Gral Paz Y Av De Los Corrales
#
#   TIPO_DE_CALLE  COMUNA      pos x      pos y   PARTICIPANTES    ACUSADO  ID  \
# 0       Avenida       8 -58.475340 -34.687570       Moto-Auto       Auto   1
# 1      Gral Paz       9 -58.508775 -34.669777  Auto-Pasajeros  Pasajeros   2
#
#    Anio Rango_Edad  semestre
# 0  2016       1-20         1
# 1  2016      61-90         1

# %% [markdown]
# Comienza la búsqueda del KPI numero 1 agrupando las columnas necesarias del ETL.

# %%
df_homicidios_sum = df_homicidios.groupby(['Anio', 'semestre'])['N_VICTIMAS'].sum().reset_index()
df_homicidios_sum
# Out:
#     Anio  semestre  N_VICTIMAS
# 0   2016         1          62
# 1   2016         2          74
# 2   2017         1          77
# 3   2017         2          76
# 4   2018         1          76
# 5   2018         2          83
# 6   2019         1          56
# 7   2019         2          47
# 8   2020         1          31
# 9   2020         2          56
# 10  2021         1          54
# 11  2021         2          42

# %% [markdown]
# Se define la tasa de accidentes por poblacion.

# %%
df_poblacion = pd.read_csv('Datasets/poblacionCABA.csv')
df_poblacion.head(2)
# Out:
#    Comuna  Poblacion 2010  Crecimiento 2010-2022  Poblacion 2016  \
# 0      13          231331                  14.64          247686
# 1      14          225970                  10.19          237203
#
#    Poblacion 2017  Poblacion 2018  Poblacion 2019  Poblacion 2020  \
# 0          250522          253391          256292          259227
# 1          239129          241071          243028          245001
#
#    Poblacion 2021
# 0          262195
# 1          246990

# %% [markdown]
# Se eliminan las columnas innecesarias.

# %%
def clean_data(df_poblacion):
    df_poblacion = df_poblacion.drop(columns=['Poblacion 2010'])
    df_poblacion = df_poblacion.drop(columns=['Crecimiento 2010-2022'])
    return df_poblacion

df_poblacion = clean_data(df_poblacion.copy())
df_poblacion
# Out:
#     Comuna  Poblacion 2016  Poblacion 2017  Poblacion 2018  Poblacion 2019  \
# 0       13          247686          250522          253391          256292
# 1       14          237203          239129          241071          243028
# 2       12          217446          220476          223550          226666
# 3        4          224495          225554          226618          227687
# 4        1          214398          215850          217313          218785
# 5        7          218707          218395          218083          217772
# 6        8          195839          197311          198793          200287
# 7        6          189418          191738          194087          196464
# 8       11          196538          197678          198825          199979
# 9       15          190078          191359          192648          193946
# 10       3          191453          192113          192776          193441
# 11       5          186277          187517          188766          190023
# 12      10          168877          169358          169840          170324
# 13       9          165618          166264          166912          167563
# 14       2          158145          158180          158216          158251
#
#     Poblacion 2020  Poblacion 2021
# 0           259227          262195
# 1           245001          246990
# 2           229825          233028
# 3           228761          229840
# 4           220267          221760
# 5           217461          217151
# 6           201793          203309
# 7           198871          201307
# 8           201139          202306
# 9           195252          196567
# 10          194109          194778
# 11          191288          192562
# 12          170809          171295
# 13          168216          168872
# 14          158287          158322

# %% [markdown]
# Se suman las poblaciones para cada año desde 2016 hasta 2021.

# %%
poblacion_sum = df_poblacion[['Poblacion 2016', 'Poblacion 2017', 'Poblacion 2018', 'Poblacion 2019', 'Poblacion 2020', 'Poblacion 2021']].sum()

# %% [markdown]
# Se crea un dataframe y se renombras sus columnas.

# %%
poblacion_sum_df = poblacion_sum.to_frame().reset_index()
poblacion_sum_df.columns = ['Anio', 'Total Poblacion']
poblacion_sum_df
# Out:
#              Anio  Total Poblacion
# 0  Poblacion 2016          3002178
# 1  Poblacion 2017          3021444
# 2  Poblacion 2018          3040889
# 3  Poblacion 2019          3060508
# 4  Poblacion 2020          3080306
# 5  Poblacion 2021          3100282

# %% [markdown]
# Se elimina la palabra 'Poblacion'.

# %%
poblacion_sum_df['Anio'] = poblacion_sum_df['Anio'].str.replace('Poblacion', '', case=False)
poblacion_sum_df
# Out:
#     Anio  Total Poblacion
# 0   2016          3002178
# 1   2017          3021444
# 2   2018          3040889
# 3   2019          3060508
# 4   2020          3080306
# 5   2021          3100282

# %% [markdown]
# Se convierte la columna 'Anio' en el DataFrame 'df_homicidios_sum' a tipo de dato entero (int64).

# %%
def clean_data(df_homicidios_sum):
    # Cambiamos el tipo de dato de "Anio"
    df_homicidios_sum = df_homicidios_sum.astype({'Anio': 'int64'})
    return df_homicidios_sum

df_homicidios_sum = clean_data(df_homicidios_sum.copy())
df_homicidios_sum
# Out:
#     Anio  semestre  N_VICTIMAS
# 0   2016         1          62
# 1   2016         2          74
# 2   2017         1          77
# 3   2017         2          76
# 4   2018         1          76
# 5   2018         2          83
# 6   2019         1          56
# 7   2019         2          47
# 8   2020         1          31
# 9   2020         2          56
# 10  2021         1          54
# 11  2021         2          42

# %% [markdown]
# Se convierte la columna 'Anio' en el DataFrame 'poblacion_sum_df' a tipo de dato entero (int64).

# %%
def clean_data(df_homicidios_sum):
    # Cambiamos el tipo de dato de Anio
    df_homicidios_sum = df_homicidios_sum.astype({'Anio': 'int64'})
    return df_homicidios_sum

poblacion_sum_df = clean_data(poblacion_sum_df.copy())
poblacion_sum_df.head(2)
# Out:
#    Anio  Total Poblacion
# 0  2016          3002178
# 1  2017          3021444

# %% [markdown]
# Se unen los DataFrames df_homicidios_sum y poblacion_sum_df utilizando la columna 'Anio'.

# %%
df_homicidios_victimas = df_homicidios_sum.merge(poblacion_sum_df, on='Anio')
df_homicidios_victimas
# Out:
#     Anio  semestre  N_VICTIMAS  Total Poblacion
# 0   2016         1          62          3002178
# 1   2016         2          74          3002178
# 2   2017         1          77          3021444
# 3   2017         2          76          3021444
# 4   2018         1          76          3040889
# 5   2018         2          83          3040889
# 6   2019         1          56          3060508
# 7   2019         2          47          3060508
# 8   2020         1          31          3080306
# 9   2020         2          56          3080306
# 10  2021         1          54          3100282
# 11  2021         2          42          3100282

# %% [markdown]
# ### 🚀 Primer KPI

# %% [markdown]
# Se calcula la tasa de homicidios por cada 100,000 habitantes y se guarda en la columna 'tasa' del DataFrame df_homicidios_victimas.

# %%
df_homicidios_victimas['Tasa'] = (df_homicidios_victimas['N_VICTIMAS'] / df_homicidios_victimas['Total Poblacion']) * 100000
df_homicidios_victimas
# Out:
#     Anio  semestre  N_VICTIMAS  Total Poblacion      Tasa
# 0   2016         1          62          3002178  2.065167
# 1   2016         2          74          3002178  2.464877
# 2   2017         1          77          3021444  2.548450
# 3   2017         2          76          3021444  2.515354
# 4   2018         1          76          3040889  2.499269
# 5   2018         2          83          3040889  2.729465
# 6   2019         1          56          3060508  1.829762
# 7   2019         2          47          3060508  1.535693
# 8   2020         1          31          3080306  1.006394
# 9   2020         2          56          3080306  1.818001
# 10  2021         1          54          3100282  1.741777
# 11  2021         2          42          3100282  1.354715

# %% [markdown]
# Se crea una nueva columna llamada 'Tasa Anterior' en el DataFrame df_homicidios_victimas, que contiene la tasa de homicidios del año anterior.

# %%
df_homicidios_victimas['Tasa Anterior'] = df_homicidios_victimas['Tasa'].shift(periods=1, fill_value=0)
df_homicidios_victimas
# Out:
#     Anio  semestre  N_VICTIMAS  Total Poblacion      Tasa  Tasa Anterior
# 0   2016         1          62          3002178  2.065167       0.000000
# 1   2016         2          74          3002178  2.464877       2.065167
# 2   2017         1          77          3021444  2.548450       2.464877
# 3   2017         2          76          3021444  2.515354       2.548450
# 4   2018         1          76          3040889  2.499269       2.515354
# 5   2018         2          83          3040889  2.729465       2.499269
# 6   2019         1          56          3060508  1.829762       2.729465
# 7   2019         2          47          3060508  1.535693       1.829762
# 8   2020         1          31          3080306  1.006394       1.535693
# 9   2020         2          56          3080306  1.818001       1.006394
# 10  2021         1          54          3100282  1.741777       1.818001
# 11  2021         2          42          3100282  1.354715       1.741777

# %% [markdown]
# Se calcula la variación porcentual de la tasa de homicidios en comparación con el año anterior.

# %%
df_homicidios_victimas['VARIACION_TASA'] = (df_homicidios_victimas['Tasa'] - df_homicidios_victimas['Tasa Anterior']) / df_homicidios_victimas['Tasa Anterior'] * 100
df_homicidios_victimas
# Out:
#     Anio  semestre  N_VICTIMAS  Total Poblacion      Tasa  Tasa Anterior  \
# 0   2016         1          62          3002178  2.065167       0.000000
# 1   2016         2          74          3002178  2.464877       2.065167
# 2   2017         1          77          3021444  2.548450       2.464877
# 3   2017         2          76          3021444  2.515354       2.548450
# 4   2018         1          76          3040889  2.499269       2.515354
# 5   2018         2          83          3040889  2.729465       2.499269
# 6   2019         1          56          3060508  1.829762       2.729465
# 7   2019         2          47          3060508  1.535693       1.829762
# 8   2020         1          31          3080306  1.006394       1.535693
# 9   2020         2          56          3080306  1.818001       1.006394
# 10  2021         1          54          3100282  1.741777       1.818001
# 11  2021         2          42          3100282  1.354715       1.741777
#
#     VARIACION_TASA
# 0              inf
# 1        19.354839
# 2         3.390562
# 3        -1.298701
# 4        -0.639451
# 5         9.210526
# 6       -32.962628
# 7       -16.071429
# 8       -34.466480
# 9        80.645161
# 10       -4.192745
# 11      -22.222222

# %% [markdown]
# Se reemplazan los valores infinitos en la columna 'VARIACION_TASA' del DataFrame df_homicidios_victimas con el valor 0.

# %%
df_homicidios_victimas['VARIACION_TASA'] = df_homicidios_victimas['VARIACION_TASA'].replace([np.inf, -np.inf], 0)

# %% [markdown]
# Se redondean algunas columnas a dos decimales y se cambia '.' por ','

# %%
def clean_data(df_homicidios_victimas):
    # Redondeamos a 2 decimales y cambiamos el punto por coma
    df_homicidios_victimas = df_homicidios_victimas.round({
        'VARIACION_TASA': 2,
        'Tasa': 2,
        'Tasa Anterior': 2
    })

    # Cambiamos el punto por coma en las columnas específicas
    df_homicidios_victimas['VARIACION_TASA'] = df_homicidios_victimas['VARIACION_TASA'].apply(lambda x: str(x).replace('.', ','))
    df_homicidios_victimas['Tasa'] = df_homicidios_victimas['Tasa'].apply(lambda x: str(x).replace('.', ','))
    df_homicidios_victimas['Tasa Anterior'] = df_homicidios_victimas['Tasa Anterior'].apply(lambda x: str(x).replace('.', ','))

    return df_homicidios_victimas

df_homicidios_victimas = clean_data(df_homicidios_victimas.copy())
df_homicidios_victimas
# Out:
#     Anio  semestre  N_VICTIMAS  Total Poblacion  Tasa Tasa Anterior  \
# 0   2016         1          62          3002178  2,07           0,0
# 1   2016         2          74          3002178  2,46          2,07
# 2   2017         1          77          3021444  2,55          2,46
# 3   2017         2          76          3021444  2,52          2,55
# 4   2018         1          76          3040889   2,5          2,52
# 5   2018         2          83          3040889  2,73           2,5
# 6   2019         1          56          3060508  1,83          2,73
# 7   2019         2          47          3060508  1,54          1,83
# 8   2020         1          31          3080306  1,01          1,54
# 9   2020         2          56          3080306  1,82          1,01
# 10  2021         1          54          3100282  1,74          1,82
# 11  2021         2          42          3100282  1,35          1,74
#
#    VARIACION_TASA
# 0             0,0
# 1           19,35
# 2            3,39
# 3            -1,3
# 4           -0,64
# 5            9,21
# 6          -32,96
# 7          -16,07
# 8          -34,47
# 9           80,65
# 10          -4,19
# 11         -22,22

# %% [markdown]
# ### 🚀 Segundo KPI

# %% [markdown]
# Se filtra el DataFrame df_homicidios para obtener solo las filas donde la columna 'VICTIMA' es igual a 'Moto'.

# %%
df_homicidios_moto = df_homicidios[df_homicidios['VICTIMA'] == 'Moto']
df_homicidios_moto
# Out:
#                       ROL VICTIMA       SEXO  EDAD  FECHA_FALLECIMIENTO  \
# 0               Conductor    Moto  Masculino    19  2016-01-01 00:00:00
# 2               Conductor    Moto  Masculino    30  2016-01-03 00:00:00
# 3               Conductor    Moto  Masculino    29  2016-02-01 00:00:00
# 4               Conductor    Moto  Masculino    30  2016-01-24 00:00:00
# 5    Pasajero_Acompañante    Moto  Masculino    29  2016-01-26 00:00:00
# ..                    ...     ...        ...   ...                  ...
# 682             Conductor    Moto  Masculino    41  2021-12-11 00:00:00
# 684             Conductor    Moto  Masculino    24  2021-12-11 00:00:00
# 686  Pasajero_Acompañante    Moto   Femenino    18  2021-12-18 00:00:00
# 687  Pasajero_Acompañante    Moto   Femenino    43  2021-12-20 00:00:00
# 688             Conductor    Moto  Masculino    27  2022-01-02 00:00:00
#
#      N_VICTIMAS FECHA_SINIESTRO HORA_SINIESTRO  \
# 0             1      2016-01-01       04:00:00
# 2             1      2016-01-03       07:00:00
# 3             1      2016-01-21       05:20:00
# 4             1      2016-01-24       18:30:00
# 5             1      2016-01-24       19:10:00
# ..          ...             ...            ...
# 682           1      2021-12-02       01:10:00
# 684           1      2021-12-11       23:00:00
# 686           1      2021-12-13       17:10:00
# 687           1      2021-12-20       01:10:00
# 688           1      2021-12-30       00:43:00
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  COMUNA  \
# 0    Av Piedra Buena Y Av Fernandez De La Cruz       Avenida       8
# 2                           Av Entre Rios 2034       Avenida       1
# 3     Av San Juan Y Presidente Luis Saenz Peña       Avenida       1
# 4               Av 27 De Febrero Y Av Escalada       Avenida       8
# 5                 Nogoya Y Joaquin V. Gonzales         Calle      11
# ..                                         ...           ...     ...
# 682                             Av. Gaona 3655       Avenida      11
# 684                    Baigorria Y Victor Hugo         Calle      10
# 686                          Av. Riestra Y Mom       Avenida       7
# 687                    Au Dellepiane Y Lacarra     Autopista       9
# 688                        Av. Gaona Y Terrada       Avenida      11
#
#          pos x      pos y     PARTICIPANTES      ACUSADO   ID  Anio  \
# 0   -58.475340 -34.687570         Moto-Auto         Auto    1  2016
# 2   -58.390403 -34.631894         Moto-Auto         Auto    3  2016
# 3   -58.387183 -34.622466    Moto-Pasajeros    Pasajeros    4  2016
# 4   -58.444513 -34.684759  Moto-Objeto Fijo  Objeto Fijo    5  2016
# 5   -58.500959 -34.608254         Moto-Auto         Auto    6  2016
# ..         ...        ...               ...          ...  ...   ...
# 682 -58.476337 -34.621406         Moto-Auto         Auto  683  2021
# 684 -58.519894 -34.622849         Moto-Auto         Auto  685  2021
# 686 -58.433538 -34.645616         Moto-Auto         Auto  687  2021
# 687 -58.467398 -34.651178         Moto-Auto         Auto  688  2021
# 688 -58.472934 -34.619847       Moto-Cargas       Cargas  689  2021
#
#     Rango_Edad  semestre
# 0         1-20         1
# 2        21-40         1
# 3        21-40         1
# 4        21-40         1
# 5        21-40         1
# ..         ...       ...
# 682      41-60         2
# 684      21-40         2
# 686       1-20         2
# 687      41-60         2
# 688      21-40         2
#
# [294 rows x 19 columns]

# %% [markdown]
# Se agrupa el DataFrame df_homicidios_moto por el año ('Anio') y se suma la columna 'N_VICTIMAS' para cada año.

# %%
df_homicidios_moto = df_homicidios_moto.groupby(['Anio'])['N_VICTIMAS'].sum().reset_index()
df_homicidios_moto
# Out:
#    Anio  N_VICTIMAS
# 0  2016          63
# 1  2017          59
# 2  2018          61
# 3  2019          48
# 4  2020          32
# 5  2021          46

# %% [markdown]
# Se crea una nueva columna llamada 'N_VICTIMAS_ANTERIOR' en el DataFrame df_homicidios_moto, que contiene el número de víctimas de años anteriores.

# %%
df_homicidios_moto['N_VICTIMAS_ANTERIOR'] = df_homicidios_moto['N_VICTIMAS'].shift(periods=1, fill_value=0)
df_homicidios_moto
# Out:
#    Anio  N_VICTIMAS  N_VICTIMAS_ANTERIOR
# 0  2016          63                    0
# 1  2017          59                   63
# 2  2018          61                   59
# 3  2019          48                   61
# 4  2020          32                   48
# 5  2021          46                   32

# %% [markdown]
# Se calcula la variación porcentual en el número de víctimas de accidentes de motocicletas en comparación con el año anterior.

# %%
df_homicidios_moto['VARIACION_VICTIMAS_MOTO'] = (df_homicidios_moto['N_VICTIMAS'] - df_homicidios_moto['N_VICTIMAS_ANTERIOR']) / df_homicidios_moto['N_VICTIMAS_ANTERIOR'] * 100
df_homicidios_moto
# Out:
#    Anio  N_VICTIMAS  N_VICTIMAS_ANTERIOR  VARIACION_VICTIMAS_MOTO
# 0  2016          63                    0                      inf
# 1  2017          59                   63                -6.349206
# 2  2018          61                   59                 3.389831
# 3  2019          48                   61               -21.311475
# 4  2020          32                   48               -33.333333
# 5  2021          46                   32                43.750000

# %% [markdown]
# Se reemplazan los valores infinitos o indefinidos por 0 en la columna VARIACION_VICTIMAS_MOTO.

# %%
df_homicidios_moto['VARIACION_VICTIMAS_MOTO'] = df_homicidios_moto['VARIACION_VICTIMAS_MOTO'].replace([np.inf, -np.inf], 0)

# %% [markdown]
# Se redondea la variación de víctimas de moto a dos decimales.

# %%
def clean_data(df_homicidios_moto):
    # Redondeamos la variación a 2 decimales y cambiamos el punto por coma
    df_homicidios_moto['VARIACION_VICTIMAS_MOTO'] = df_homicidios_moto['VARIACION_VICTIMAS_MOTO'].round(2).astype(str).str.replace('.', ',')

    return df_homicidios_moto

df_homicidios_moto = clean_data(df_homicidios_moto.copy())
df_homicidios_moto.head()
# Out:
#    Anio  N_VICTIMAS  N_VICTIMAS_ANTERIOR VARIACION_VICTIMAS_MOTO
# 0  2016          63                    0                     0,0
# 1  2017          59                   63                   -6,35
# 2  2018          61                   59                    3,39
# 3  2019          48                   61                  -21,31
# 4  2020          32                   48                  -33,33

# %% [markdown]
# ### 📥 Carga de los datasets

# %% [markdown]
# Se guardan los dataframe transformados como `Tasa_homicidios_moto`, `Tasa_homicidios_victimas` y `homicidios_final`.

# %%
df_homicidios_moto.to_csv('Datasets/Archivos_PBI/Tasa_homicidios_moto.csv')
df_homicidios_victimas.to_csv('Datasets/Archivos_PBI/Tasa_homicidios_victimas.csv')
df_homicidios.to_csv('Datasets/Archivos_PBI/homicidios_final.csv')
